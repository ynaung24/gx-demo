# %%
import pandas as pd

# %%
good = pd.read_csv("./sample_data/good_data.csv")
bad = pd.read_csv("./sample_data/bad_data.csv")

# %%
good
# Out:
#    player_id            player_name       team  points  assists  rebounds  \
# 0        101           LeBron James     Lakers      28        8         7
# 1        102          Stephen Curry   Warriors      32        6         4
# 2        103           Kevin Durant       Suns      26        5         8
# 3        104           Jayson Tatum    Celtics      30        4         9
# 4        105            Luka Doncic  Mavericks      35       10         8
# 5        106            Joel Embiid      76ers      29        3        11
# 6        107  Giannis Antetokounmpo      Bucks      27        6        12
# 7        108           Devin Booker       Suns      24        7         5
# 8        109           Jaylen Brown    Celtics      22        5         6
# 9        110          Anthony Davis     Lakers      25        2        13
#
#     game_date  minutes_played
# 0  2024-01-15              38
# 1  2024-01-15              35
# 2  2024-01-15              36
# ...

# %%
bad
# Out:
#    player_id            player_name       team   points  assists  rebounds  \
# 0        201           LeBron James     Lakers       28        8         7
# 1        202          Stephen Curry   Warriors  invalid        6         4
# 2        203           Kevin Durant       Suns       26        5         8
# 3        204           Jayson Tatum    Celtics       30        4         9
# 4        205            Luka Doncic  Mavericks       35       10         8
# 5        206                    NaN      76ers       29        3        11
# 6        207  Giannis Antetokounmpo      Bucks       27        6        12
# 7        208           Devin Booker       Suns      abc        7         5
# 8        209           Jaylen Brown    Celtics       22        5         6
# 9        210          Anthony Davis     Lakers       25        2        13
#
#       game_date  minutes_played
# 0    2024-01-15              38
# 1    2024-01-15              35
# 2  invalid-date              36
# ...
